# %%
import sys, os
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from sklearn.datasets import load_iris
from typing import cast
from sklearn.utils import Bunch
import pandas as pd
from shared import eda_tools as eda

# %%
iris_bunch = cast(Bunch, load_iris(as_frame=True))
iris = cast(pd.DataFrame, iris_bunch.frame)

# %%
eda.data_overview(iris)
# Out:
# Shape: (150, 5)
#
# Data Types:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object
#
# Missing Values (isnull):
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
#
# Summary Statistics:
#                    count      mean       std  min  25%   50%  75%  max
# sepal length (cm)  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal width (cm)   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal length (cm)  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal width (cm)   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5
# target             150.0  1.000000  0.819232  0.0  0.0  1.00  2.0  2.0
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# ...

# %%
eda.plot_target_relationships(df=iris, target="target", ncols=2)

# %%
eda.correlation_heatmap(df=iris, target="target")
# Out:
# Correlations with target:
#  target               1.000000
# petal width (cm)     0.956547
# petal length (cm)    0.949035
# sepal length (cm)    0.782561
# sepal width (cm)    -0.426658
# Name: target, dtype: float64
